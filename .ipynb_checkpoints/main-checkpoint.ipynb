# %% [markdown]
# # LSTM for Generating Shakespeare Text
#
# by, Udaikaran Singh

# %%
import torch as torch
import numpy as np
import matplotlib.pyplot as plt
import string
import torch.nn as nn
import random

# %%
from models.lstm import LSTM
from models.gru import GRU
from models.vanilla_rnn import Vanilla_RNN

# %% [markdown]
# ## Preparing Dataset

# %%
all_chars = string.printable
num_chars = len(string.printable)
file = open('./shakespeare/hamlet.txt').read()
file_len = len(file)

# %%
def get_random_seq():
    # Get a random sequence file
    seq_len     = 128
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

def seq_to_onehot(seq):
    # Convert the sequence to one-hot tensor.
    tensor = torch.zeros(len(seq), 1, num_chars) 
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

def seq_to_index(seq):
    # Convert the sequence to index tensor.
    tensor = torch.zeros(len(seq), 1)
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

def get_input_and_target():
    #sampling from the file in general
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# ## Training

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
net = LSTM(num_chars, 100, num_chars, device)

# %%
# Number of iterations.
iters       = 50000  # Number of training iterations.
print_iters = 100    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.Adam(net.parameters(), lr=2e-4)
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:99/50000 loss:4.546998977661133
# LKUfOSyk; sequence: W5 j84BVgR!9SI8
# Yvx!r3.WMd:z6 -7r'~#&l&5?0nTV:g\}>nz-(4f.i 5ylZ'SP? fdJWn17oJ+n*"
#
# iter:199/50000 loss:4.416583061218262
# generated sequence: WBi%_W'm a{~Fo,	d3qW>vX[$vQaOer>TIxY6ZtuP2&[
# JHUGd]-yZci6<T\*56uM'k ]\~@T}&ieegn|DpqptVdMX|S?#aw@^Xu
#
# iter:299/50000 loss:4.140929222106934
# generated sequence: WgPX_tIwSJ>hrann`eb!Dn~%tP}i0k:)Aao&/kwp]:(To?z]v$IOyF&r	)dnShc=
# Fw
# aFksXmX\~S+h-[os<sA%QV'KGJsQLI#1
#
# iter:399/50000 loss:3.8073153495788574
# generated sequence: WadrNeg]bRrht:N0 r>9Ncor* l
# 3eq<&#	 z7nnisebdMc
# co
# ?mtrrh3i u|oTnp sh zaRtevifRtRUln/D}	"l }IBys	T
#
# iter:499/50000 loss:3.541747808456421
# generated sequence: WtL F"A
# NreewQ2ye.fH hety	ZyoLm
# D)oTlaghTsoish
# sZ inig Ie#
# rw0, ddNhwnetce0- H?eej) iCrraOKbtt@e`tt
#
# iter:599/50000 loss:3.4031262397766113
# e ;oei f ot2Gnrrw	x.a E geeyse  ae dDu.R d m m niatdnl	=+rM t iaoeoe toasvn[o :xshasi
#
# iter:699/50000 loss:3.3270790576934814
# generated sequence: W ostyo nt o yrhdnINs!gLt.iiea(a'doayrnwrd s borafitem rgy r JndE	h!fohEt3p	oiogtte,s f oh'hbmhY:ohef
#
# iter:799/50000 loss:3.2868404388427734
# generated sequence: W orldg
#  a sbB onwtnan	0iedw dt  w s  o*s ayh  leHdetwisct2etsehuoauE- i,.e iddN.aIKoldew-i ,F'aynihe
#
# iter:899/50000 loss:3.2890398502349854
# generated sequence: W ouatolosmtt AMRORcrc  fonp
# ui\ pdthusamrroFcasiEtsa octhhs!eb hWohesonne ofe io onlii,renr  ne d	(
#
# iter:999/50000 loss:3.2475531101226807
# generated sequence: W rntalaetuioae
# yihf  or eot
# Pce
# iwe ee y r  otvn 	6 Ioifsh	yNFeaAo baw dot }n
# wu
# sIatoah.vwee ,r	Q
#
# iter:1099/50000 loss:3.2191061973571777
# generated sequence: WaOrAHmt t	d r c iExarh %a	u}hlOhnhehae, wsreii
#
# uw  se ti oi4c nr A'usgO}I
# dUh
#
# 	TriHyaystshttro
# [
#
# iter:1199/50000 loss:3.1405951976776123
# generated sequence: WhoT,n oyh
# ;inn	oSNW so ow tt u e tmikshA ecoot ; aiy otAS
#
# sHel soeeera otafh a M' d? hg yi ]Iora
#
# iter:1299/50000 loss:3.158649206161499
# generated sequence: W oR<a h ealheolem s
# DLhim  sale	+urse aw sht fn tno  :t hft teWrgiaP, yeere
# on s r  cwcum
# 	o.DtTh y
#
# iter:1399/50000 loss:3.1042938232421875
# generated sequence: W ar asisy%e ay m,
# h d r
# rlenA]oh wisovhe r i iisoteor?rii   r t 	fbb.  tfrhe uo tes.hiSaainD tti t l
#
# iter:1499/50000 loss:3.0824320316314697
# generated sequence: Wbm 	 tautist n:
# toa' on ut $ ostom 	 ta w hehi !isttenrWg nh '?ced oroI:n amoer
#
# iter:1599/50000 loss:3.0055594444274902
# generated sequence: Wrr imronSqbsr oowd lop eeheolnku
#
# gs ,afd  hei,wta mHsllres h tg hcs te0ue ny, ytyyno
# USrhveRrpalc
#
#
# iter:1699/50000 loss:2.9920578002929688
# generated sequence: Wlsl eew  ctnuro rhay u kTey,Hf E@.:hn:
# K?	Fd th nh tly t	,
# 	- nma ut bnofssshewagkenrrennd T
# 	0w, nm
#
# iter:1799/50000 loss:2.981302261352539
# generated sequence: Wthane Nre p aivisr e inhlal f nithrs outhee i -Aftosnm r.
# uin en.
# 	atol d eaouol!
#  nf del bm d n'k
#
# iter:1899/50000 loss:2.939150094985962
# generated sequence: Wmhev,-ntrltvoro st rwed innut,d ou  t	T it ra l n	e ririanso,s a pis
# 	lapI m|mn tw,,n; sue inLran t
#
# iter:1999/50000 loss:2.922766923904419
# generated sequence: W,
# 	AIssohite G y M thsa*del ir R*Kaifmei tnart  aadvaoot bpn sts so 5Lw
# ,r, t sdmC 'n fhensothbov d
#
# iter:2099/50000 loss:2.877225875854492
# generated sequence: Wti.x tos tlinid noe 	"h seilsdovcfls at niHee E8to(e fhedid tor  t hi onitas
# a ,ev  ? Tim Ialelws P\
#
# iter:2199/50000 loss:2.871791124343872
# generated sequence: Wi?irrhedisonuthe e f,
# 	Z ,OC,,d wneG  ThaanflveutAushe g
# 	tity hna
# 	,d d teagd tids f^atMIP
#
# 	'ed d
#
# iter:2299/50000 loss:2.8173820972442627
# generated sequence: Wide,y, keafi ofjeror w om
# 	'ar nrooSRYonnd ,aDerlor.
# 	-e GO cehanothyhwmec t s faIe apnritsyofdHfopa
#
# iter:2399/50000 loss:2.7868499755859375
# generated sequence: W; f Berol sroinoreu lor k.
# 	Bm nos learL8iton.
# 	w atiinymis kte oneEgabeedw'CSn'c fanhurge pcha.
# 	Ge
#
# iter:2499/50000 loss:2.8236708641052246
# generated sequence: Wy	it d t two he horhehour HU	k wisd,i, uOMSTLEAlEThdmtm selAEv,
# 	-eatheeangeumoure f {+cees to s e
#
# iter:2599/50000 loss:2.7523891925811768
# generated sequence: Wheol fe, mR?
# 	Vohaorle fn'uror r sfaEFolvoedobouaneetaar n E6I	ALNderane yb hden l twhtg r isatEIsgo
#
# iter:2699/50000 loss:2.7205076217651367
# generated sequence: Werilarier lilofehno get al xs
# 	sth:
# 	TitheI mn l tiIrTeuucon vil ncast m d arlelaoon. cos aomumaser:
#
# iter:2799/50000 loss:2.7125601768493652
# generated sequence: Waranf hee mot raptheath iraftag od ilenw n, rasor
# 	&rhoCThta, ahe at ws ey myeser monthe serth tvede
#
# iter:2899/50000 loss:2.7145111560821533
# generated sequence: Ws mithle inm.
# Hatenathy d ;r wAt
# helinkolilylin
#
# 	Tine.anorlamesouhend b rouss'latheitA m atv  , sme
#
# iter:2999/50000 loss:2.6692962646484375
# generated sequence: Wate ts.
# weroaf h el
# 	towhe e the n ace n y s gyolakist eWh che.	Aven esa'toun; p ht uuEpeSN meh,
# 	TI
#
# iter:3099/50000 loss:2.689000129699707
# generated sequence: WetEMeay  .
# 	SRGeropkinmthar s J.
# 	Eithend ne sdinlimak sJ omelopMualep?therth re tthd Tohes, hesh sh
#
# iter:3199/50000 loss:2.6636083126068115
# generated sequence: W'he, angiy eyoubyo banT.
# 	Tciverpe h, aL.
#
# 	rot RAFithe5lne he thirertsr Biiery n.
#
# 	AT   cokobeeli
#
# iter:3299/50000 loss:2.6783785820007324
# generated sequence: Woue phete
# 	he totnsin apan ainialen uuceshudoes sine
# 	T iriremor t n thec s
#
#
# KreA'the s : tIptw gL,
#
# iter:3399/50000 loss:2.6593105792999268
# generated sequence: Whilrenthevhis nthecea ], n t$oe tintere mellisan  h; oou th'e theott thimouthirts wO,o rt Ie omoangr
#
# iter:3499/50000 loss:2.6573073863983154
# generated sequence: W ur nd aanyo t.
# 	LETONOAtashens jaerkve
# 	he d ldo his  a ys lhesiuel anond f blN.
#
# 	; we U:
# 	y i mha
#
# iter:3599/50000 loss:2.6071882247924805
# generated sequence: Wsofn, KOOHeasofuth anditsiliban whimer w: T	WhetouwhiATK	Oheoled bee
# 	N ou'MC,yis mdismhett
# touos li
#
# iter:3699/50000 loss:2.623570442199707
# generated sequence: Whiavelenre mosag]
# -lf le f hot,
# 	ig  s mer me komiy mtosthamtherthort thl.
# 	arEThEUM hes
#
# 	Are e
# 	IT
#
# iter:3799/50000 loss:2.6258533000946045
# generated sequence: Whhinerd Ain-, arsagere andethe hoety d, p
# 	Aho s icul, thaso y be mderereh fnoganar ry lda'be.
# 	Hr
#
# iter:3899/50000 loss:2.610297918319702
# generated sequence: Watpa f nsve wIUKTG	Wint ishA3# t, pinIer mon wos y o:ild t touor ION tos than,
#
# 	S ay fy HAcpifitars
#
# iter:3999/50000 loss:2.615567922592163
# generated sequence: W beorni, m s enZR' lu lpl ws criy oma b:his y sfund sd cpel p, te monmast e p s hof moudet, ouvif o!
#
# iter:4099/50000 loss:2.5946805477142334
# generated sequence: Whd want gt aemsy teves W; ke
# 	W d sung urind rade'snith
# 	Ten wot af e  f,es w.
# 	Tho impallee
# LMT
# rss
#
# iter:4199/50000 loss:2.5791122913360596
# generated sequence: Whisif tau sper af'i.
# -Iur feitinis.
# EMLAT	Ethe,
# 	Tht nd sd iltk f me whe, h amathe le n 'd,
# HIgae he
#
# iter:4299/50000 loss:2.5608115196228027
# generated sequence: Whe g inRhecord aisy,
# 	[Awagfonsrheonhe f insowenmy g bnounisatud	Aather at s wouiis borer t ir mon's
#
# iter:4399/50000 loss:2.608283281326294
# generated sequence: Wisthe ctoed
# 	HAr stheilnouksegot O	S	I-Thetoare chisr dar saloos CORBsg]e f, d,
#
# l.
# 	1 fesirth oud t
#
# iter:4499/50000 loss:2.5808346271514893
# generated sequence: Wnoly oss . bu a blendathatheond hand ty  wisceno mine is agonseteo.
# L.
#
# 		L2 willlencowhe welo'dethe
#
# iter:4599/50000 loss:2.573136806488037
# generated sequence: W men and ond h aco .
# 	NWour,
# 	TOle doftongtim in mhenge fwilthuodt e;
# 	A@ ady t tiwo'lupskit y y the
#
# iter:4699/50000 loss:2.588068962097168
# generated sequence: Whfs I ans mat oud [s ar is he s lsoirge w, s halRDR;
# S ptr iy P	| ve
#
# 	ERELAgwlhewhealgbave hir  t a
#
# iter:4799/50000 loss:2.560340642929077
# generated sequence: Whandance
#
# 	I, whe  yh,es hanethipin is I
# 	T vede batar:
#
#
# 	PO beforid y yepathalin thas obuosL scand
#
# iter:4899/50000 loss:2.546825408935547
# generated sequence: Whit t owisado atheranth  anind, plOoul Dy the ny bly d, me g an bur deooweras ztimeagend,
# 	When, t g
#
# iter:4999/50000 loss:2.571730136871338
# generated sequence: Whyachisebe at w I
# 	zO	I:
# SDRDe h th sey w
# 	Thathtpe hp monf ill veermis lbafen ure ELEI: indyhe ?
# 	T
#
# iter:5099/50000 loss:2.5443875789642334
# generated sequence: Wat pHArolmlu
# 	NFo y anit, sr anr madininodt way he st hersin, o ms ur tothar canishiouece imile
# 	ISR
# iter:5199/50000 loss:2.5436081886291504
# generated sequence: Wthamive tharou whes?
# 	Hity thigousea, sorox w, derdem?
# 	T	Tit m h wve:ed IO	IUd t I a, bl lu per pen
#
# iter:5299/50000 loss:2.551567792892456
# generated sequence: W'ssovetr tot'gayo me b vel yechisd d tasanesfa,
# 	USLfihatosne
# 	Waleang ofisd wory s wolkeit the gp b
#
# iter:5399/50000 loss:2.5253562927246094
# generated sequence: Whoule atoyo s I ton qus cry pinepl wE| weethas ad;
# 	Ypathlle t I"ighe bis cotarigoureomes st men w o
#
# iter:5499/50000 loss:2.540379047393799
# generated sequence: Whiavour coulajus dive phishe  rshente le islosoraras th mre Fowthes,
#
# 	BmIofe Ior ber ne, frs tePTS
#
# iter:5599/50000 loss:2.5053114891052246
# generated sequence: Wath u ad tist gofondo f rs ion llo mun, polllUS	yon cam, lle toqwi! wighilofos moas l stthoufamad HA
#
# iter:5699/50000 loss:2.532816171646118
# generated sequence: Whe k keravof athe  )t,
# 	A, s hor it dcito IUSoyis mose,
# 	ERWhasikfonomer.
# 	I.
# RMLAman, he eserl nthe
#
# iter:5799/50000 loss:2.512366771697998
# generated sequence: Whad as sinot ist he ll wid? ket;
# HAmndest, INTDalle tivey th ss-Hicherind lle'my ad thery, t 	HALENF
#
# iter:5899/50000 loss:2.521594285964966
# generated sequence: Whoketbele c uinthe y nthatet tind othimas mita femy winge sour;
# 	B, thusy d, st, o aeit w mlabemiveo
#
# iter:5999/50000 loss:2.5354487895965576
# generated sequence: Winur p ouran]
#
# HERwIwathisanyoano
# HA'st s me  e Ther;
#
# 	I
#
# 	OV m
# 	T	Whollt Thar,
# 	Bakate d wisobe, b
#
# iter:6099/50000 loss:2.518218755722046
# generated sequence: We csf f sd Housgefelerce ce n ar eamoe momout ome oveth, kfousele mu d is ha l wofran:
#
# 	Buot f ve,
#
# iter:6199/50000 loss:2.520905017852783
# generated sequence: Woue bugothinoryouleipint; srgmyoing ralalovethert iver, HA%SET t tr geslr, levenond mithe f mewou n'
#
# iter:6299/50000 loss:2.5186896324157715
# generated sequence: Wh s w
#
# 	[RDtanfofatoith me mue al owrpeme s el.
#
#
# 	[Nwee 	Vrsro
# MLT	Omue t outalam mely y f owisha6t
#
# iter:6399/50000 loss:2.4878900051116943
# generated sequence: Weacl m,rinorrgnsit asuo mave NBs is y hainderery ade, 'eere fods archas ler: f hol maPuse y phheiio,
#
# iter:6499/50000 loss:2.5173356533050537
# generated sequence: Ward wasthelloho thinelont be 's ake onotundon al cat-our!
# 	,
# 	Whas g,
# 	. n;
#
# Nerallarid hthulo har f
#
# iter:6599/50000 loss:2.5001749992370605
# generated sequence: Whell,
# 	INbost: mllowessthe d amathighe ar k': C	Whedr'llfthe y, thaf in d m gnin the,
# 	IESesorCLEN	A
#
# iter:6699/50000 loss:2.5420849323272705
# generated sequence: Whaf but ctol d t:
#
# 	Tiste fal inen, it enulof ist ow mo-  l I tue'. sof t dourtUETLI'd sthe ss fere
#
# iter:6799/50000 loss:2.5155985355377197
# generated sequence: W	T	[ERTo IAMLELET	T	Ave;
# 	NCRAMAMLEN	Aphel r ir.
# 	SLEThe hand e be ae;hutot alle I'neso ope all haat
#
# iter:6899/50000 loss:2.5196990966796875
# generated sequence: Whist  tolemertilorrtthe w be ou ssente afaclld my mes becor n merd s PIOLETh ,  for, r mee Cad, ingo
#
# iter:6999/50000 loss:2.5046417713165283
# generated sequence: Weepllonceray he y farlr the,
# 	Hdedo pe weveyest LAsar iesdve thik ucha ks fa; my'velllara.
# 	Nwoman l
#
# iter:7099/50000 loss:2.4985485076904297
# generated sequence: Whepts asort y apse.
# 	P
#
# 	Malltomitirathe be arata n onn,
# QUIUDof is loucs'CS	Fas eks mis t gor, t.
# H
#
# iter:7199/50000 loss:2.5100324153900146
# generated sequence: We heneine d pthin fe bortooin id, chor;
# 	[DENlouan ct sullad: y serd.
# 	herdind.
# Q/ve., ndg limyradti
#
# iter:7299/50000 loss:2.5143918991088867
# generated sequence: We IIThut o
# 	|'nvat mteexer:
# 	And;onofuveane akse ar co rontrrs sen os n t kit eam-IUDUERC	OGe, heasi
#
# iter:7399/50000 loss:2.4858505725860596
# generated sequence: Wad t h, l:o to!
# 	HOSORAMLThe, t]
# LAOMAnis, ut hyoung thinced thorath r t d s hanmo ss, ser n icku Gt
#
# iter:7499/50000 loss:2.489389657974243
# generated sequence: Whithis acouyuy, I forchar the ireeis thot ethe sn	NI st inokrasr yofotoutearouvatho hist inde d m:
#
#
# iter:7599/50000 loss:2.5052220821380615
# generated sequence: Whernowy PLERI tor,
# 	[IAMLELO	USanof, t atrinthe-the hesu'w. s wmhpinmarir!
# MLEN,  m cay acuiealyof't
#
# iter:7699/50000 loss:2.508394718170166
# generated sequence: Wh mepeste t orl d by foi,
#
# 	TTAnn t f eneast
# HAxiET	?
# 	IDORAnd: pe a;
# |Ieabr ath ILellloun  f  polsm
#
# iter:7799/50000 loss:2.5109446048736572
# generated sequence: We t ing ancor his f d m'thetlit d ho mlind, hare
#
#
# 	Whe ikiw t pt w i the t lind;al, pGouthacan sous
#
# iter:7899/50000 loss:2.4862279891967773
# generated sequence: Whe the,
# 	IThthis d belyowhafalan gdd pthee d g ait: thd: he, cinoid breredouthtu h ss fo f othesirhe
#
# iter:7999/50000 loss:2.492008924484253
# generated sequence: Wand ce  f cowha!
#
# 	Ho lowholles maneul'd s h pes le trtos t t nkelou n andin qu an, hinous d;
#
# MLDou
#
# iter:8099/50000 loss:2.466252326965332
# generated sequence: We I
# 	MLAVllt re inolras,
# 	MLAM tenis; s co lanesoprdrimepor m a o, th, ae ltIOLOV! d we t pr thad in
#
# iter:8199/50000 loss:2.4868032932281494
# generated sequence: Whantof W! lir:
#
# 	Nmut agiuis j:
# 	And,
#
#
# HONTERAMLELAMLG ve mle d:  irlsunsthit therthin path he pnd
#
# iter:8299/50000 loss:2.482008695602417
# generated sequence: Wa  y t ar p af t fte tr wendon gtrri!
#
# 	| agategenomatont-owecpucandHAromour, wh, ilallandouthun ng
#
#
# iter:8399/50000 loss:2.491208076477051
# generated sequence: Wheere,
# 	Dee thido I]''dcain, ye s ar aws phowithe.
#
# 	RTEERONSs LORAMLA	A Ge.
# 	Aau lourpor
# 	LET	MLI n
#
# iter:8499/50000 loss:2.488819122314453
# generated sequence: Wheronen df o he in eas clldos woutr m, NHANBur hee, ht o irelodiond winge he.
# 	MLENo: aceeeaver, hin
#
# iter:8599/50000 loss:2.486654281616211
# generated sequence: Whtlin sin [at Tomeve iler  HAsthand s h thine irlomere alod h ang tay heven d itillabll omle ldofofs
#
# iter:8699/50000 loss:2.474963903427124
# generated sequence: Whe mll wielat we
# 	IOHAMDI d anofth mat as; s terigheow,, madt th, toreay, y thody my t me thar y med
#
# iter:8799/50000 loss:2.4868361949920654
# generated sequence: Whtromove jothavothig. thero hit g l ey isiseseelat's ollerdse HAne ellayof wa, terountce heeputillly
#
# iter:8899/50000 loss:2.4948301315307617
# generated sequence: Whofowot!
# 	he jond,
# 	IAnd?
# H, itoo'litur og the, marl,  is couthathily moud sidhais allang
# 	Panchat n
#
# iter:8999/50000 loss:2.4933245182037354
# generated sequence: Whans
#
# Hoes;
# 	NIAMLOSRNouven havang ak ut  y thr tor ; wnd e, s!
# 	Wthay de fet,
# MLEesd hety t ay rest
#
# iter:9099/50000 loss:2.485013723373413
# generated sequence: Whe stlerert
# 	Fost the Pf ffis th itherdatoy  r issorananot Histpadoud.
# 	The, cheer  thaercalkef y,u
#
# iter:9199/50000 loss:2.4797093868255615
# generated sequence: Wr co lisvevepe w t avevereatos ]
# 	[Eandanthe m s, f haverenc cle,
# 	OR?
#
# HATLOgou? vis po hitd ay tev
#
# iter:9299/50000 loss:2.4765350818634033
# generated sequence: Whours
#
# OHO	'puselkinoue d;
# 	 ofs lite  h hanourl il! coicill bitw s teemeLENDINT	Sos w:
#
# 	Wh  a r f:
#
# iter:9399/50000 loss:2.505707025527954
# generated sequence: W, for o endst acenopheayove maoll e od, lat ml IUS	AMLEC	S-Oncoplfor mathe hither  woio arkentperede
#
# iter:9499/50000 loss:2.484551429748535
# generated sequence: Whise s we.
# 	Whorthay eretherfishe ched by waghitheeergh Hou ce eloueth il, d m owil  iced nournd ane
#
# iter:9599/50000 loss:2.480962038040161
# generated sequence: We thaorde hipathileagend afud:
# 	wheafdoreennto e,
#
#
# 	ITian wimounf os sarefite ther Hlithefoour ws I
#
# iter:9699/50000 loss:2.459075927734375
# generated sequence: Whe'.
#
#
# 	Bein
# KI w han in  dalacomy t?
#
# 	Wherinbeoenoth wru Mfh ss d tl t s ndanoule'stf berchive won
#
# iter:9799/50000 loss:2.4768171310424805
# generated sequence: Whin.
# 	Aicknn melamore leerapodofa he prt,
# 	PBely tnd hin mo Kwave,
# QUS	[AUSin in, ong	COrout semy ck
#
# iter:9899/50000 loss:2.500281572341919
# generated sequence: Wuncaeru wlif th g myothay mitr olacost.
#
# 	TI man,
#
# 	WaiigAnokyond bece Pome lly t j;
# 	ANSe mewyole t
#
# iter:9999/50000 loss:2.470789909362793
# generated sequence: Whethedenors, t thene'med me ant, lerermey ad oun, hine t mie avertoyor d ino st, w bal n pareene sma
#
# iter:10099/50000 loss:2.481687545776367
# generated sequence: Whe qur blye, bes of e nd ithith Ge-he leris GI-
# 	Drego me Hom s wowhefas bof ut ootoul mm winselommo
#
# iter:10199/50000 loss:2.459761142730713
# generated sequence: Whes myou d atisopsiod 'the llin. pusterin? lreblors the ur g y, atourzuavear curm?
# 	Vere,
# 	MLstelof
# iter:10299/50000 loss:2.4882373809814453
# generated sequence: Wyondnch HO
# 	GEacotof leceetar haflly mangr hat,
# KI? ce an;
# HIRTZ	T	kill hedes aist Thad t?
# 	TE	C	Hou
#
# iter:10399/50000 loss:2.468371629714966
# generated sequence: Whes f' hous ange.
# 	TZullat,
# 	CLONEn t courd s s.
# KAMLI hen, ilong atr
# 	al mpachathmim m 'coTh r ashs
#
# iter:10499/50000 loss:2.46097993850708
# generated sequence: Whes omesth whenped, ilerpae!rantheray'dongios faset s le-
# 	Mavemener s thesblft f ifowhisht wees' go
#
# iter:10599/50000 loss:2.4521324634552
# generated sequence: Wanidima  tlo t y llind! wh thir thavengadeo'bornoutun in be pl t l IUSELE	O cat IERORA ! ne m?
# Hever
#
# iter:10699/50000 loss:2.463228225708008
# generated sequence: Whephf hor s.
# 	CERNS	AMLA''le-
# 	S	Alithe,
# Frs s deeld woullf heat it herooGhing athon fatay a'one rth
#
# iter:10799/50000 loss:2.459005355834961
# generated sequence: WameleN th m osthaatythendothes.
#
#
# 	HERD gerr: :
#
# 	He 'ck arn hith he udTheacourethat omer's,
# LETheco
#
# iter:10899/50000 loss:2.47819447517395
# generated sequence: WOowid nsth ateasusfadondou wowit d! relurtho tdunbedinest swhsulaled? mene d
#
# LET	of Pw lllly thof g
#
# iter:10999/50000 loss:2.4658427238464355
# generated sequence: Whpu widelit, Pz. pl nou t s ' it hatoit ofosoor,
# 	NROS	Thild.
#
#
#
# 	ato t: ty d ised nge io  acthanges
#
# iter:11099/50000 loss:2.438387870788574
# generated sequence: We mowlllor teein aran he a'd tce, y INIUERet s ched t llswisha when wothet e lrs, ss cy my.
#
# HAMyeeC
#
# iter:11199/50000 loss:2.4800798892974854
# generated sequence: Whethethilly, weirdou t wtlnourliland.
#
#
#
# 	I
#
# 	AV	O	Wous?
# HAn'o k winkeroule blitegharalavero s  bers
#
# iter:11299/50000 loss:2.4562408924102783
# generated sequence: Wh h t
# 	Thenntr cenounge is  is maers fu anvelachenou foryotis, t d ttinakinnfouesuta y w ch overeres
#
# iter:11399/50000 loss:2.458092212677002
# generated sequence: Wengr s om becis therny t oponous youloron hid.
# 	DI meag  cachisesy th his veThi cldsinendtanowenser
#
# iter:11499/50000 loss:2.44561767578125
# generated sequence: Whathen and.
# 	AMLAExud
# He ge; afore a l ior a t this t POS	Thathoy kit s t d, s te mn stour'ARAf g fo
#
# iter:11599/50000 loss:2.472761392593384
# generated sequence: Whie ingan	zes's cotee mteso thelly ld ansthimer on ace, d n, th hin tol t halleritte w? in nn POFake
#
# iter:11699/50000 loss:2.434443473815918
# generated sequence: Wis leafyo ariots w.
# 	I QUDETIo betoue isis f wsh foulld th.
# 	SET	I
# 	sore fis s, gave mandert lllul
#
# iter:11799/50000 loss:2.461671829223633
# generated sequence: W;
# HO et  be hy. adou.
# 	I-mor fthoth,
# 	Herd endyores  mathemere me s: t wisthin boveleldENEN	I me'd o
#
# iter:11899/50000 loss:2.4437756538391113
# generated sequence: Whomangsisparod s y, s IUSNAUSCes me qurerschone ue fit nspus f how,
# KIUIakiro ore s ganourd omauices
#
# iter:11999/50000 loss:2.463681697845459
# generated sequence: W f, k.
# 	INDI ct y roucthesath se t sinar s:
# 	AMEE	IUSCS the
# QUS	AUE[POPHathatingheer INLI'chindin,
#
#
# iter:12099/50000 loss:2.4612603187561035
# generated sequence: Whad l
# LO	nong ge as sowat t athallo onss tthithus ntfr y t, ve:
#
# 	an bord t: poumTomonditherno po an
#
# iter:12199/50000 loss:2.47090220451355
# generated sequence: Wul wo   f nkane he Irond
#
# BESEN: dsmins athorilas hest t poveue mre  serr le byous
# 	I ld attoultanes
#
# iter:12299/50000 loss:2.446004867553711
# generated sequence: Whay omu, avellato  ir t---noneas  herg omus mechi'm iery bl nou utisithy ILORTofowis ssuhert h h htu
#
# iter:12399/50000 loss:2.4400346279144287
# generated sequence: Wafatholome, t t  ise onbe be coula
# 	neak
# LAMLe, thar trppr t CLImo pr' andoreathe ai, mpe sth we wil
#
# iter:12499/50000 loss:2.470827102661133
# generated sequence: Wes!
# 	YNedst
#
#
# 	uleshie wshe wpcok sespe inothe yeet r, h:
#
# 	HA on se.
# 	Tod otheromcemoonove, thistho
#
# iter:12599/50000 loss:2.462282657623291
# generated sequence: Wik,
# 	IUDononther s myoumedeete may thamoube ind t. h,
# 	sisen KIou-t ce wyo  S	MLD w tes t, g thofopl
#
# iter:12699/50000 loss:2.4832775592803955
# generated sequence: Whes, S fatuncthe,
# 	wharerd it.  IUD
#
# 	As soungo yr ar,
#
# 	Hod our.
#
# 	Whes be bore IUInthe, t batinbey
#
# iter:12799/50000 loss:2.4611425399780273
# generated sequence: Wirt y d thy.
# 	BuretietisCof pasg hencofral-'errod
#
# HATh,
#
# SOEThind s amtonde
#
# KI.
#
# 	ar;
# EN	n
# 	Whin I
#
# iter:12899/50000 loss:2.476102352142334
# generated sequence: Whoveabro, AMLOLETh ofalirsast ishoor
#
# QUf iledended shetes
#
# Q uro ndarn sed tiley he m.
#
# 	I con bren
#
# iter:12999/50000 loss:2.4773807525634766
# generated sequence: Wis avie, m the, ie  may HAnldas t?
#
#
#
# O by oshibre wio c,
# MLORDo f we r, fay ishin ud s chere mas f
#
# iter:13099/50000 loss:2.445890426635742
# generated sequence: Whasencow l han ce MLEThethiascefesantre  aneeinsotwrsclonofre; me foind ' llldomin s Goury atho gano
#
# iter:13199/50000 loss:2.4278922080993652
# generated sequence: Wit hour tnt,
# 	T	Ivo w fot mucone totheerit be nig
# Helay.
# M| HO	F:  any  t.
# 	Toce shellive shtojowcod
#
# iter:13299/50000 loss:2.4551897048950195
# generated sequence: Wefais helend we thono sthar wh n,
# 	red ar
#
#
# Hal t, t s ane senolt sidst mamarisoorers hestham s arpa
#
# iter:13399/50000 loss:2.47092342376709
# generated sequence: Whithere st fes her prar nd bat?
# 	T	RUIALOLAM.
# 	Sutede, tortule amt ghoger d PAMAMAndylled chy, Pitha
#
# iter:13499/50000 loss:2.4449379444122314
# generated sequence: We.
#
#
#
#
# HAnd?
# 	Thanoe y tchagowcarss;
# 	Wayon IUS-ar CETI s co aru nget' HAnen g sanfus a. ke,
#
# 	n cly
#
# iter:13599/50000 loss:2.4482884407043457
# generated sequence: Ws h m heaeerd nod s;
#
#
# 	I it, it,  d. scof olis th tElld ' bl?
#
# 	Whant,
# 	AMeine kiordeca ame ar an:
#
# iter:13699/50000 loss:2.4484708309173584
# generated sequence: Wholeririnaist sallse f; d ishtwhe'T	AMLOulr, eate t QUDhixaut yofrd go thinor a'chely ims d vend so
#
# iter:13799/50000 loss:2.468579053878784
# generated sequence: W[RToly ?
# 	ORATIourateveave len irther Vwrt yondoreru boomathay alyet ouereckilos geanedey Py e, s, b
#
# iter:13899/50000 loss:2.4522128105163574
# generated sequence: W's wow p; homa ou  IUSeyozche
# Fourlakes  frenisthend, wnca l n f trthe w'cathay y aveconkntg ath mon
#
# iter:13999/50000 loss:2.4584972858428955
# generated sequence: We lomeezow
# G we co s ch I INI he driot tpier monon thukit; Gin o bouce ss mso RAare ailitolacheeoou
#
# iter:14099/50000 loss:2.4324424266815186
# generated sequence: Wherthaaeshe !
# 	Hear PORAMat rETed ielle.
# 	TINofo lonty wer, lUS	Bulyeapes  swithat t thilinwor nd po
#
# iter:14199/50000 loss:2.4532196521759033
# generated sequence: Whe alad HARanou will howeses thes.
#
# 	CLETRD pn mf  mrere mee IOLEQUS	[ET	atof ferat'sha oaf nsowicow
#
# iter:14299/50000 loss:2.447964668273926
# generated sequence: Wimen spotwhe, d.
# 	Bu wite in BETZ	Afoowis cel'de k,
# 	T;
# Halll,
# 	PORDERThis  t itig bugh d.
# 	LOorl si
#
# iter:14399/50000 loss:2.459035634994507
# generated sequence: Wh'd y t ou hes,
# 	ro ame CRTerdowrd, pth,
# [LETout ntard an pl, atheait plingins,.,
# 	BEESB:
# 	B? Le ta
#
# iter:14499/50000 loss:2.452681541442871
# generated sequence: Whein hire,
# Gwit; LESENERAnand
#
#
# HE
# 	enthecanos; adcourk. ote tirand s OROnse gr me be]
# 	Deer thinge
#
# iter:14599/50000 loss:2.419353723526001
# generated sequence: Whiveamurtheimeetherd tiedelonke PORI yonghef anpas, hirer othu the omy wut cke, chreas d wavereatir
#
# iter:14699/50000 loss:2.4601826667785645
# generated sequence: Whin DEs deercelovewatsather f oliour'ssareestorithis ET	Ghindpaker anison ali mrad! and RNooun l h o
#
# iter:14799/50000 loss:2.4724724292755127
# generated sequence: Whes angiowar abyo.
# 	Yos. he t he le seal che ongharean sp inmeck Gs hikn'POLES	tarowi	TIUDIlensoe ce
#
# iter:14899/50000 loss:2.4477808475494385
# generated sequence: Wilorglur'g o he pe,
# 	S	[ETI fe heas, thikes nwede as yus.
#
#
# HA, im merede p frt bute s myoudse.  thi
#
# iter:14999/50000 loss:2.471759557723999
# generated sequence: Wht withackeiss ma d hal tusequrtouthe t mag.
# Hofer sthiy, omft had.
#
# Horticar yond al eavoisoll;
# 	O
#
# iter:15099/50000 loss:2.4474027156829834
# generated sequence: Whan we iththos aknirtpo ryRT	T	HAMLIUDETonoullo:
# 	 oury d.
# HAMLE	w G ket ou here t,
# 	Wat tis win, bu
#
# iter:15199/50000 loss:2.4638593196868896
# generated sequence: Wher wn st, t atwo, wit he rececofad g bro yenthad.
#
# 	Siou d hoothall ce medildstreveathyospe o!
# 	Fan
#
# iter:15299/50000 loss:2.4439423084259033
# generated sequence: Wheat, perivernd aerdigone,
#
# 	Hor w atonum thilsoupere k furin ainomy ake ther s the w he t nat hay:
# iter:15399/50000 loss:2.430703639984131
# generated sequence: Whoo ornd t'sletiouve densem amarenokgethes ad y bur arearis hod Fousee.
#
# 	[RA
#
#
#
# 	Ye HAn NTHarighast
#
# iter:15499/50000 loss:2.4546000957489014
# generated sequence: Wh,
# 	tais: ngim;
# 	MLO	ngea athe.
#
# 	hamacor beck, vez: chiral'monrend mayor omyor ORDEAt s t   ht m, p
#
# iter:15599/50000 loss:2.462552309036255
# generated sequence: Wh doul. te ghe his y' inof mour n ongd l  at, ver s.
# 	V	ORUSEThaspeaventher A] ar hiro fankest
# HARAU
#
# iter:15699/50000 loss:2.44980525970459
# generated sequence: Whatay  POBEo hof thy, par he aikn t tend thend,
#
#
# 	COLUS	O	|talin'coe whengre
# 	Ck,
#
# 	Bert Fr hithase
#
# iter:15799/50000 loss:2.454129695892334
# generated sequence: Whe tie Ipit,
# 	AMard: mpot uln ' theshoulath he;
# HAManonppe fr l wiar w feerat isu gers ane t br like
#
# iter:15899/50000 loss:2.447659730911255
# generated sequence: WI Isce. his LERousthad theparcorierend the l
# 	MLERTERDoupe s int s,
# 	ane s
# 	NCL	Hathayoga the aly s
#
# iter:15999/50000 loss:2.45609188079834
# generated sequence: Wee l Mo simstt tungf owuraliceavitoy s me f thiwheseletheraves in leullg,
# 	IUCmy fly. fffd, f aksvin
#
# iter:16099/50000 loss:2.436406135559082
# generated sequence: Wh ano kibe birise thearinongas id gam,
#
# 	I wing.
# 	ath,
#
# 	Nill nngo bed hendoimy  ftot ko h ofemalo o
#
# iter:16199/50000 loss:2.464308738708496
# generated sequence: Wher: POTis ss IOG tite w o
# 	edol, ty tis the?
# Le ad s hashofkevitithe theme
# HAMLENThe y, grdond mofo
#
# iter:16299/50000 loss:2.447507381439209
# generated sequence: Waivir BETouroff cel len
#
# 	y moumof sthe he incis thagerdads, te hes s br pa  h  ben fimend ENire?
# 	W
#
# iter:16399/50000 loss:2.441925525665283
# generated sequence: Wancorblly g me t y s'd jofly mef w's, so yudithandivet lisick my  y angldave, myouny,
# 	| ve 'atjld!
#
# iter:16499/50000 loss:2.457894802093506
# generated sequence: Wisis sclofof veniaunk.
# 	INIUI hersty m TEThate
# 	Seang r	Wonstit ances otourelr,
#
# 	ThimCELT	MLD--ncoo
#
# iter:16599/50000 loss:2.449354887008667
# generated sequence: Wourancinsoroos ber't my:
# 	An my  my Ta, m le l; an and e G-r demondrinit theat, s ar,
# 	[ELC	Touveese
#
# iter:16699/50000 loss:2.4577219486236572
# generated sequence: Whditharen bericunin ty.
# 	F'd waredy,
#
# 	Nove ithischitata n	HAMhinou gt.
# HAToustiowne mfomewen: t 'd
#
# iter:16799/50000 loss:2.4706473350524902
# generated sequence: We?
# 	Abristey hanche irspase's.
# 	TEThe:ghar LENthory s is dutht  brc: se perisime se, afan ll, y pr G
#
# iter:16899/50000 loss:2.4481256008148193
# generated sequence: Withayobet richonot pl,
# Had e ce alase herobuclorugeaed, CE, medines f an ous, t ds,
# 	INEExgellertous
#
# iter:16999/50000 loss:2.466062068939209
# generated sequence: Wh hithit:
#
# Horos, thofet y POzath nd'  Forours y wererg!
#
# 	YNINT
# 	IfI ha.
# HES	antod; t orit.
# GENAnd:
#
# iter:17099/50000 loss:2.449558734893799
# generated sequence: W an?
#
# 	ATRT	S	HAMLAn ieelle By h out h t hove ble
# ORThestou, IUWhind fl handlll, t oracean k pas; CL
#
# iter:17199/50000 loss:2.445197582244873
# generated sequence: Whar defas thet on wnRA	To isane dus h otoch yomunse. sgou, imfin
# HAThanato thegfico y Helenot kst,
# L
#
# iter:17299/50000 loss:2.443120002746582
# generated sequence: Wine'thlousou, ges lor: live line wce or ine lt.
# 	Anthatis mane LE	t the en	[USicexinothyor whiessos:
#
# iter:17399/50000 loss:2.442859172821045
# generated sequence: Whr gore t't plimbr---Who: he?
# 	G s ?
#
# 	An ler lfen ffe.
#  prde th th'aiHis Dhiget ftherd  h heyomenun
#
# iter:17499/50000 loss:2.4286301136016846
# generated sequence: Whiredelamyese lliriathe oft an he is bebesondsoily y heako sofinthisu omy POLD it thine ha us oug'th
#
# iter:17599/50000 loss:2.4384043216705322
# generated sequence: Wh s pre s, f  s.
# 	[ERAnes tom, ie rs heldy; ouve haly cre, PHAthand rullothe Gishilo f urnghoouco d
#
# iter:17699/50000 loss:2.417107343673706
# generated sequence: Whathathen, e aticere t ou avisoud f wathind overenset t oud s womelde	AAExely, beeeje t HAMAUScouner
#
# iter:17799/50000 loss:2.4185855388641357
# generated sequence: Whaemullaarayo,
# 	Yo apizes w puneanour,
# 	Isatheot hat gst:
# 	Asoforainkint;
# 	Hepent s m iofanocert myo
#
# iter:17899/50000 loss:2.4299988746643066
# generated sequence: Why Thachegre gel?
# 	Wheaoont mise GERT	I frl owiranche melline d PO	srun gowinve CE	Sithe auchyru s b
#
# iter:17999/50000 loss:2.4699344635009766
# generated sequence: We theromspre;
#
#
# QUDI yed lase PHAng  blome awhitinchalinombele.
# 	Tomelis tho O]
# LOLORARUS, by,
# 	Ad.
#
#
# iter:18099/50000 loss:2.439504623413086
# generated sequence: Wiust oldeeriore t, g se Whu wacheak	T	Whithr cry, oe llldease, t gurfowar honst at
#
# 	GUDI harseeren
#
# iter:18199/50000 loss:2.46128511428833
# generated sequence: Ws acof loushenat iliouterthard il IORCy as ve t IUS	Bur' IO	A Isomor thene th sore ee oouthit g's, w
#
# iter:18299/50000 loss:2.4257402420043945
# generated sequence: Whawhe
# 	[ETinpe   thetlo d horeborise by find  hele codintonooul oochie s,
#
# 	Aneiced HARo nded me e w
#
# iter:18399/50000 loss:2.4498403072357178
# generated sequence: Winome---d o he  oren ecouean G rAMLONTh k G ilamooule wrg.
# 	GELExtesst hefu mut h bes ine kne guthe
#
# iter:18499/50000 loss:2.4310970306396484
# generated sequence: Wis.
#
# Giebe ld rod y!
# F y tantan	AUI h d, aneryou s d s cthahr,
# 	AUEn]
#
# 	[DELENClar y C	Hong pl benth
#
# iter:18599/50000 loss:2.446979284286499
# generated sequence: Whalk hee othasul ctht
# 	IUS	T	HARNerr y, thallorel. ghos, wis 'd t ay bre d, f lotistchan?
# HAMay hik
#
# iter:18699/50000 loss:2.426750421524048
# generated sequence: Wit gs,
# 	thernd Go; d
# 	T	oond, ivy  the spe. Yothat. his d, erse, r,
# HAs e winde h tl f ksar,
# 	LENOrl
#
# iter:18799/50000 loss:2.406635046005249
# generated sequence: Whtag iler, a n G tt cullidonthsthig thilir sso. de.
# 	Wh falyo ousu w s llle fl ayove, chucalourserak
#
# iter:18899/50000 loss:2.432743787765503
# generated sequence: Whoure.
# 	[EThileucullld y wandan wnd dot oy thatorpor t mrno  telethe asem
# 	HAMLolere, ou ve:
# 	Js ows
#
# iter:18999/50000 loss:2.433300018310547
# generated sequence: Wht f d co atowirik anget ole, ve iry, I w owoff th pre monele the merwe be himan, hond bl oil trt mo
#
# iter:19099/50000 loss:2.461280584335327
# generated sequence: Whinocats's marde, oitind
# 	DET	Ise gourinifo fe 'sond ofend. gefow t omat'pamayon he tht dithe o'scai
#
# iter:19199/50000 loss:2.468597650527954
# generated sequence: Watoo perant mor ifourd, his k tiss sge tcad clashes ud y Gowy se nche  pand it?
# 	HO ak heyoff s ud.
#
#
# iter:19299/50000 loss:2.4267520904541016
# generated sequence: Wim; tyous, tu ke g, he G tird tw
#
# 	TELand is]
#
# 	IA s ga h mee ilail POS	T	I fay ais,-e hierope wis h
#
# iter:19399/50000 loss:2.4298043251037598
# generated sequence: Wo my oug, d ghe'em  rs lins t Pive ta fonowim an a  CRI io t Cemenghashe thidnthe blgourf he alieto;
#
# iter:19499/50000 loss:2.444260358810425
# generated sequence: Wof vey;
#
# LLI IONNakinon'n G]
#
#
# 	Wim f  I b?
# 	Thiyos hesr come, st chicand?
# HONay ist 'sacofuest w ma
#
# iter:19599/50000 loss:2.4354286193847656
# generated sequence: Wh, whh Doe n]
#
#
# 	NIoofrimithaoumesindioume fibuce is t d LENTONTELererinchen sbrpberiourica bur avea
#
# iter:19699/50000 loss:2.4496383666992188
# generated sequence: Whbf
# 	Ifod fuil inerde onng pange? t hatitory wes;
# RORAnn.
# 	t are amyotatalou wingsof osousthay.
#
# 	HA
#
# iter:19799/50000 loss:2.4280970096588135
# generated sequence: Whyk t pwine oun, busenghand.
# 	S th k fontuloderd e as whimeas grnthe t temend  yof d s!
# 	Fale athari
#
# iter:19899/50000 loss:2.4546453952789307
# generated sequence: Wh, il If d
# 	Hermice ty timy.
# MLERy I r'Toe: frithonge Clert]
# 	ESCETIUSRDILORORDT	T	[Z	| I RO	ING t?
#
# iter:19999/50000 loss:2.437171220779419
# generated sequence: Whig acowano her, thilouresstoupaico, y brtalllade, t orold.
# 	Soy candr, he,  utcantes y. Ppapr  s po
#
# iter:20099/50000 loss:2.449373483657837
# generated sequence: Wown menoveakreangr hesowout G	LEng ct iat; wimemavereriondeca alos.
#
# 	IAsthere'l: ankne bremy moour
#
# iter:20199/50000 loss:2.4427883625030518
# generated sequence: Whe Foinrulordoremarous hiranot tatst'abethemof
#
# 	Asinswom y d;
# 	Anifar becons]
# 	T	IUS ct-reld ve by
#
# iter:20299/50000 loss:2.4386518001556396
# generated sequence: Whkimy,
#
# 	AUS	I ETh padin fat he youshar ut sthaclC	TZ	[ne yogheind Ufoplithis wwofmem we
# 	Bouthepave
#
# iter:20399/50000 loss:2.4146504402160645
# generated sequence: Wiser: th Cot it, ans caveandes  a w w whe an cl, anth G and t, malouvemishend orithats mvofalthe we,
# iter:20499/50000 loss:2.429457664489746
# generated sequence: Whtharseis.
# 	IUELENI we, melato vemy. d wean:	T y; izers:
# 	[T	n aserin llacathe t thasthealitsiy roug
#
# iter:20599/50000 loss:2.4440817832946777
# generated sequence: Woorige
# 	Whepayoond I sthe powae t cu ece bres, ant re t.
# 	Ishtut, ghin] bife d na wgoo GERA]
# HORO	gh
#
# iter:20699/50000 loss:2.423853874206543
# generated sequence: Whis s erfly y titoursclithis'ss n:-ve tagat t om HARAres.
#
#
#
# 	MLAnugurs's wert.
# 	AES
# LE	MLETaso h t
#
# iter:20799/50000 loss:2.45627760887146
# generated sequence: Whed wick:  vef (cho deth cel howin pbeerotwMLar! amor. sethorpr s, ve d 'lo QUS	Wild, bl ose hytos,
#
#
# iter:20899/50000 loss:2.4574434757232666
# generated sequence: Went k in h thind the hasowesitomespily y yoe ste my t.
#
# 	TItucoo G by, to
# 	Ha t weerur melly soughie
#
# iter:20999/50000 loss:2.444843053817749
# generated sequence: Whed o mares, r.
# MLIUERA hed thimee cotin marave t-ty.
# HATheau kinos owiholoer ucralls n	S	The ooves,
#
# iter:21099/50000 loss:2.450962781906128
# generated sequence: Wiveeshe.
# 	UDILAMynd hir ovee;
# 	ACLOS	T	Whom mand?
# 	Hbar cond wwha fipreant y, hery,
# Haradausengusula
#
# iter:21199/50000 loss:2.434194564819336
# generated sequence: Whth
# 	AMyous cer ipirmyogit ceck ofoy I''et IUDENCLORDExt RIt hearce conobelithinet thincoreranfo h
# M
#
# iter:21299/50000 loss:2.4401586055755615
# generated sequence: Wh ous ound whin fetwind POf n conf at br t s mede arere PFour--n fon sherur o le iouno ary f e s coo
#
# iter:21399/50000 loss:2.4484832286834717
# generated sequence: Whos, hthkill thadsayow t, mad pook:  tha iccend, avououianofr herl, thent]
#
# 	[ERTExeringerousitoumae
#
# iter:21499/50000 loss:2.4546239376068115
# generated sequence: Whimin the tas m r	ONAs lltwhis, rorthhe irveppatmpe vespais
#
# 	my she MLofothingolllandow ondavivos:
#
#
# iter:21599/50000 loss:2.4648287296295166
# generated sequence: Witond geeyd n, tayo; y wemad thgrcth
# HAMLAnd we laud y w;
# O
# KICoomlet MLEl hamamu ck'd sir withed t
#
# iter:21699/50000 loss:2.450099229812622
# generated sequence: Wiry,
# 	Wilathathee.
# 	Wik w
#
# 	A
#
# 	Yo nge pr t; r. witveit s'd,
#
# Hatt my y lowiun m, t;
# 	MLET	It hauaku
#
# iter:21799/50000 loss:2.4497432708740234
# generated sequence: Whethaber ind t l  onm, thinou: chefin geleasathas he,
#
# 	INAUD r.
#
# 	OSouthofowoo tas  ke! elo io Hil,
#
# iter:21899/50000 loss:2.446316957473755
# generated sequence: Wha'Thig, m wne atr, ueef p p noldloonsthonaf se gu
#
# LILEdorc acesofle: an a foitor ie :
# 	Gomyoucat s
#
# iter:21999/50000 loss:2.4379703998565674
# generated sequence: Wiol ile, witor sth tthougo N mus? ls,
# 	t theboorisoveango,
# Hees
# 	I whhabresit,
# HORDlou.
# 	T
#
# 	Whar pe
#
# iter:22099/50000 loss:2.4421231746673584
# generated sequence: Whe we wowhe'rs, thinbu se s t d asherdsthin
# 	HATe--
# HAMLETRUSan'eatre iomorlrthesinthinonsrdoullly w
#
# iter:22199/50000 loss:2.4255709648132324
# generated sequence: Whio fthandion s vitin benkeceloul oraingayour
# KI arouraky mery kisthird r d CLIIth.
#
# 	Wh hartie heit
#
# iter:22299/50000 loss:2.423905372619629
# generated sequence: Whajursthatal RUS,
# 	suld keras hin glonghee m iCouby's, s d ansthent, thilord oue k sur, bold Cath ab
#
# iter:22399/50000 loss:2.466252326965332
# generated sequence: We owingof cas y
# LAMLDor w yood.
#
# ) fole kit bldeadt doun HAUS. ngofin d ct]
# LORO(QUDen  TRA't heven
#
# iter:22499/50000 loss:2.4472739696502686
# generated sequence: Wh V
# Hosde msporoure arsthshe ctono oout, t
# 	LERUSET	Ghot--ha le thavenday t haas 	NGhesese oma kel t
#
# iter:22599/50000 loss:2.4180023670196533
# generated sequence: Whol t weghe makur ndan OPs
# 	A's a iffricgllun yorst be;
# HAENCRO	Bon, phe r d, deet Yometh he titller
#
# iter:22699/50000 loss:2.445444107055664
# generated sequence: Whainke on allf PO	Fou y s, ll hindld on.
#
# 	MLORD sheeleay h y. r thowe it huemplkigr t ded iokied OR
#
# iter:22799/50000 loss:2.4311940670013428
# generated sequence: Whondeatnge d thishise thindind r tire hy winthI mbe ate, hack dime! we,
#
# 	Whe ber helit hid'dith uth
#
# iter:22899/50000 loss:2.4515180587768555
# generated sequence: Woo fe DI-r whes and aris mph  autes LENZ wy s ededeabis at weatheteteliunderurt id iser reld cos ms
#
# iter:22999/50000 loss:2.4484658241271973
# generated sequence: Whanout:;
# KI nour ankn bomy
# 	Yont athin t: therd  yowhs ch aist ee; t IUERIUIUDol, r d relite t dildr
#
# iter:23099/50000 loss:2.4278364181518555
# generated sequence: Werayis aco FLiray osove yeay Curndo
# 	 at iendur atedof ait wis LOPA t;
# 	LAMLI y phind ou llan e maun
#
# iter:23199/50000 loss:2.4197771549224854
# generated sequence: Whered pule harsthothe---ay wingrapoow's ay thl nne ghathin he nt
# 	Weld t p ngt ETIle.
# 	MLEnds?
# LAr u
#
# iter:23299/50000 loss:2.439809560775757
# generated sequence: Witenomy, powee?
# , wg ow
# HOn n.
# 	TZ	MLENWhen, ithalloto ak brs ad pp othan wes ws
# 	inge ide  Ifee. e
#
# iter:23399/50000 loss:2.403059482574463
# generated sequence: Winuf anay tovetomu anayoutonone, isply,
# PO	Cll iy Hay wnoutomelst hifave at ttins.
# LEThel
#
#
# ES it th
#
# iter:23499/50000 loss:2.4108150005340576
# generated sequence: Whed
#
# KIfohabilo ouvie esuviseeucet imst AMLEr me cay may asthen.
# 	peaile in, al hicke w
#
# 	I enomes.
#
# iter:23599/50000 loss:2.4282419681549072
# generated sequence: Whisore t;
# 	tisherd moushes eet pe je
#
# LAMLUS	OR t d as pr cs micherd a CLDICRUI cenene, stit mayoome
#
# iter:23699/50000 loss:2.445397138595581
# generated sequence: Whin;
# 	Cots ind lf FOSRAMLDI- are t avo bise car?
# Hebelle th maw
# HAUShek athatitus r s?  atlousor ien
#
# iter:23799/50000 loss:2.4468417167663574
# generated sequence: Whevergexerillise lere D rnelss aveser; ar, ull s myotlef ocy
# 	ONghe t we UETe
# 	's.
# 	Whof II dou, myo
#
# iter:23899/50000 loss:2.432661533355713
# generated sequence: Whetupahis  atotie tisu, atio o w,
#
# 	Ry.
# 	I thermyor-Fouliner gyollas ores,
# 	G tordserthik
# 	r,
#
#
# 	AML
#
# iter:23999/50000 loss:2.4432170391082764
# generated sequence: Wis hiffathanowit y?
# 	MLorderira-we s arueay: n, mot tecmougigld:
# 	Bu pend d--me s moes, e d ay ay in
#
# iter:24099/50000 loss:2.454775810241699
# generated sequence: We thickeak y, y?
# AMLo f N se wino, oulaprellthe vave, s e ist ht pas beant f mesteawice is akst t un
#
# iter:24199/50000 loss:2.4231908321380615
# generated sequence: Wheshitlivedorind ino orall opecreelothe ber INTh teronditlakim, almetesower iniey, chothan
# 	T	T	NET
#
# iter:24299/50000 loss:2.4330339431762695
# generated sequence: Whandifallacheasie inte tse as mathen bu est anthe n anothitar tont cr!
# -
# 	Sthy oo in, thighe milia w
#
# iter:24399/50000 loss:2.4270811080932617
# generated sequence: War wigindcr t horea fariothay anes sd ie
# ONont  t,
# 	[ II r netlant,
# 	ARA Thlel haralat tead,
# HAnst a
#
# iter:24499/50000 loss:2.4232664108276367
# generated sequence: Wheximinotherd outheleento,
#
#
# My t men t kerotokrs,
#
#
# 	Woole- lfoordit  Wh]
#
# 	Wh ipo, pe al ted o;
#
# B
#
# iter:24599/50000 loss:2.440100908279419
# generated sequence: Wherelad be stond hes. ba mas h Hara mas lot mart by t owhate ad theld. d;
# ONENARORAyot?
# 	We, ala ad,
#
# iter:24699/50000 loss:2.4096808433532715
# generated sequence: Wilaplou y od os isathend igo ut co
# 	D  a'e likirds h patrlro yI
#
# 	AMLARUDIUDETEx s tord wema  iripe
#
# iter:24799/50000 loss:2.441527843475342
# generated sequence: Whirallllad, thaururiloragecas tlu.
# 	I ON s, sourillloleng his?
# 	Sallthispan n'te n.-g t em dhe ak ic
#
# iter:24899/50000 loss:2.4416089057922363
# generated sequence: Whies.
# BE	[RThen y thit h deausonethy bru oof t d, hithearpinow
#
#
#
# 	W]
# 	TERDOPruch sst alenguthes las
#
# iter:24999/50000 loss:2.4194540977478027
# generated sequence: Whethise ty iears I'
#
# Q; t l, nthrithin'de wa tht  ano ho LEETI cof was metoRUS	TRORDIOLETEn KIPOPHad
#
# iter:25099/50000 loss:2.4537930488586426
# generated sequence: Wher ssthinin couthey yasts is mu arl RA lds h uen frofive u od one n w  y,
#
# 	Tole. t g sthene
# 	Haire
#
# iter:25199/50000 loss:2.4419872760772705
# generated sequence: Whemardispses bpwhend,  akinee hangendroud,
# 	[IO	Bisinth womehef my,
#
#
# 	Cors,
# 	ALuthird 'ghe. POPHo b
#
# iter:25299/50000 loss:2.4215476512908936
# generated sequence: Whau s co at tron my ]
# 	Tonimanoos ul. isigriontlds whe?
# 	By
# Qucrive f u hemathiowrilor k my we aknoa
#
# iter:25399/50000 loss:2.4307825565338135
# generated sequence: Wisthevey llwisth tts:
# 	I 	G fan hin mathishatirch wn co, y,
# Hanswen.
#
# LERT	TIUS	Yelay benclug, isesh
#
# iter:25499/50000 loss:2.434276819229126
# generated sequence: Whe
#
# Hethe, iore with t ancofal inchen hedok
# 	d is Whains
#
# 	Withio  kipeioulllld
# 	Burorund toe widlsh
# iter:25599/50000 loss:2.432143211364746
# generated sequence: Whithincollisheay of he goneatheaghat'endot.
# UDwhin ss lele trseand]
#
# 	ORAUIAng powhe jomurer n at al
#
# iter:25699/50000 loss:2.4476425647735596
# generated sequence: Whae Fouyotio hir lavil, te ithe df omou;
# 	IUS	TRARNG A	I fonmuphin y d d: inoror se RTherug.
# 	Wher F
#
# iter:25799/50000 loss:2.4392638206481934
# generated sequence: Why y, qu, m wel ous t f co but shasts, Ive spw ld,   nd.
# 	Thinges.
# She Figofous ve th s,
# 	And, IUSRD
#
# iter:25899/50000 loss:2.424777030944824
# generated sequence: Wh w IUSERThaloisthe  d foveyoucaulomere, rou-did. l IUDEN]
# 	PHeaye ngawof, grey a spe min herape t;
#
# iter:25999/50000 loss:2.414639472961426
# generated sequence: Whcreve f cik,
#
#
# 	TI ge ispesat s iwe Gothe ald tenin y wine,
#
# 	[T	|
# 	HO	HAMe nd s pothergey, weaind
#
# iter:26099/50000 loss:2.410717725753784
# generated sequence: When, fin ar anouvend r prwilispoilionvat Coueve ll,
# 	I ioondllell wie tet aboug burst  a whatatenn m
#
# iter:26199/50000 loss:2.4340291023254395
# generated sequence: Wif y ofara's stholser w alie housurt wif lor,
# 	Tomby,
# 	tw til hatwha hind han I rermto.
#
# MLENEMAMyou
#
# iter:26299/50000 loss:2.442580223083496
# generated sequence: Whesthanowoloncl hermy EMLIvithanevert s]
#
# 	ATI s f che
# 	Py?
#
#
# HAn d, st.
#
# 	I gy foiu, DELDI tre onk
#
# iter:26399/50000 loss:2.4316537380218506
# generated sequence: Whoith: houcrdeaneay, theangu lou hy.
# Fors g is by, pr, s, o thimbl onom my ul'
# OLIUS	[Engho, Halaknt
#
# iter:26499/50000 loss:2.428969621658325
# generated sequence: Whinomourourre;
#
# Hel w: win; k, idlindist fis houn'd ke angeeremo serapiss!
# 	HARNoouler  hirinfe (MLE
#
# iter:26599/50000 loss:2.4384145736694336
# generated sequence: Wheadouthawerothers l ve ashave fer mein nowame e offathef y  p np CORour os, TI athad uowise witimos
#
# iter:26699/50000 loss:2.4178974628448486
# generated sequence: Wharard oue; o'ts t  d ceshoy ad w'son, y tsstose lor, mot mat ir:
#
#
#
# 	[Hala h't
# Hod, hethe Sint imy,
#
# iter:26799/50000 loss:2.460062265396118
# generated sequence: Whe: ous.
# 	HORDo s, m, tw ls st t! wilats io a maldewow  whar myorita,
# 	Sis-RDIUDof ir, kn;
# 	ANCET	TE
#
# iter:26899/50000 loss:2.4476356506347656
# generated sequence: Whis lenn ind; thad n duret word.
#
# 	Thitrd
#
# 	OS	UE	T	Bure wor? kingule s, trt arin ustoraghoullleme,
#
# iter:26999/50000 loss:2.4315192699432373
# generated sequence: Who;
#
# 	MLETo g:
# 	ELLT,  are mld,
# 	quctis tharande
# 	O	Sico, ounde,
#
# 	AUyondor y torr.
# Hange sive, hinc
#
# iter:27099/50000 loss:2.4065163135528564
# generated sequence: Whan to andibeenurtaveall hintorearber the  anoncofowin, ardouwhome ht youngeee st, co y?
#
#
# 	' b,  ar
#
# iter:27199/50000 loss:2.425812244415283
# generated sequence: Whest ieanolece e wowatndoche gasperis orele s, wis herindeiloofinthots quntorur ldothangod wise te t
#
# iter:27299/50000 loss:2.4444000720977783
# generated sequence: Whiord and en.
# 	l, ture:
#
# 	TIOLUShise gh s od.
# LEETandy s   cuend entin the imavhe ss ld, t, theONCLE
#
# iter:27399/50000 loss:2.4315881729125977
# generated sequence: Wh,
#
# KIUENangol wakianghen mat cete w Pretharf h jurs hil'ep,
# 	Gor honot thino d d PAMAPHeofrthelamas
#
# iter:27499/50000 loss:2.4289119243621826
# generated sequence: Wher fr y.
# KI, a wexemend.
# 	N cke ostheayomte feres,
# HAngof, then ly t,
# 	UEnth, g s mend spor  h md a
#
# iter:27599/50000 loss:2.446584701538086
# generated sequence: Whintthth DO, 'scoupeayofe pusthe masuromeaves mo'llorerkeree prd t m oneree: oldofthevelen, pe Pithe
#
# iter:27699/50000 loss:2.4159488677978516
# generated sequence: Whean  lil ath aci y thiostbe hy be wiablsu ay ther e, pale nk'drenithingprelt ederd,  f  my ntir bld
#
# iter:27799/50000 loss:2.4388511180877686
# generated sequence: Wighitt t st lo wetwirin mepa owllinghan t ay UDONBuatloo  t pund o oveplor's. co, in l. ps f es myoo
#
# iter:27899/50000 loss:2.4370388984680176
# generated sequence: Welorelaksplst asene-manse whond in yo ofoler
# He ilest istin  w bof'dourf s utape ndae  ono d se t
#
#
#
# iter:27999/50000 loss:2.4158670902252197
# generated sequence: Whitume CLArtar CLO	LERDI g d be!-lllomy, bato nk I'dd fouther:
# 	e ng ndivith ith oullaret NI'thtou a
#
# iter:28099/50000 loss:2.430603504180908
# generated sequence: Wilithert thas d rthids jus an s I PHeaprel qus, me halilouraurest mint u ghe juren ot,
# QUSTorrt f f
#
# iter:28199/50000 loss:2.438926935195923
# generated sequence: Whis HO Pfe hinartho t  thifer larlorthansceke t ivelureallorimed, a t mas.
# KInt wighe, th
# HAnded rs
#
# iter:28299/50000 loss:2.4319493770599365
# generated sequence: Whepangs; e.
#
# 	AM
# 	Win st,
# KIne t  thar wis me t olonk yove arpon t t rs go'ther have y su fothe
#
# ONA
#
# iter:28399/50000 loss:2.437981128692627
# generated sequence: Whing d,
# 	IUSENolot paneaweghak maliour milour chy n,
# 	ONores t imyofove tt fu s profout ale, sesve,
#
# iter:28499/50000 loss:2.44517183303833
# generated sequence: Whar t,
#
#
#
# 	HAMLETRORNGEThanchane in s thathinstiumainted, PHe me landorus  gh
#
# 	QUIUST	Wit angak ile
#
# iter:28599/50000 loss:2.435861349105835
# generated sequence: Wer d t mea an arard isofind
# 	th dref geld htharageng I tingrest a hiris Foofe s:
#
# 	|'d, w,
# HAn ad ls
#
# iter:28699/50000 loss:2.4335408210754395
# generated sequence: Witiot fr l.
# 	HAs agover?
# Hothord,
# HAy thise noupthean! d CERDILDERTomat Whae, p t lof leecany alinde
#
# iter:28799/50000 loss:2.4328248500823975
# generated sequence: Who  whe?
#
# 	[ST	'shovebisthathy f; l.
#
# 	[ERono us t can
# QUIUDO	Ant y hin'saved s hed; wis mesispar---
#
# iter:28899/50000 loss:2.447002649307251
# generated sequence: Whicanothirad wocay. f theem t ws mes mivouthesanowove hindond d ind?
# HET w ir me'sha ppssthan hou be
#
# iter:28999/50000 loss:2.4398109912872314
# generated sequence: Whe atitt,
#
# 	[TERDELAbande Pat ointuce to wine we koushin, o.
# Rurfe it fulind thooun th thand Nonot.
#
#
# iter:29099/50000 loss:2.440760374069214
# generated sequence: Whato ityore myonout thekeneat, tht  th anthin, itheinothe y vis
#
# 	OLano ane tssthil: mur thovist
# 	UE
#
# iter:29199/50000 loss:2.44106388092041
# generated sequence: Whit he, a PHA t
#
#
# 	DOS	Tou HAMut
#
#
# MARN tuve thee RAGERA  s p t f t' kt thom r ist wasueaey
# 	[ENSo t
#
# iter:29299/50000 loss:2.43245530128479
# generated sequence: Whathers isck uerk somy s shefroneandind thr.
# 	MLELENano s! osth is m.
# 	Pamandngoru
# 	Thicoue! leat, o
#
# iter:29399/50000 loss:2.4679148197174072
# generated sequence: Wo'!
# 	ON	On. G s DOSodscifrur' ht d otheningst, ms Lot Flororme t foutod, alecthe,
# 	HA agishind f HAn
#
# iter:29499/50000 loss:2.436094284057617
# generated sequence: Wis'
# ...
# generated sequence: Whe t l iot y ithithen isisir trlis  s sencory belees stst, kicheases. ased munete ts leg. edol and t
#
# iter:40399/50000 loss:2.4323532581329346
# generated sequence: Wher gerin ond t  igeas: t pes t th,
# 	NAnen,
# 	YNEThad peid t mof
#
# 	Tho thas h myofot t G ke: t okeat
#
# iter:40499/50000 loss:2.406373977661133
# generated sequence: Wiomobllo figo pldit: meawerowerut ty tha mot
# Hathan	ay youndre mest h,
# 	[Eng Comlllosapcermlotove my
#
# iter:40599/50000 loss:2.431340217590332
# generated sequence: Whary sZ	s them'dheachayou hert: s ingin Hopeyofrtonfr mo ghey s, withisponone hireany wng intyocashi
#
# iter:40699/50000 loss:2.420515775680542
# generated sequence: Whiuch asunchaly bremelf ion, totheitheur  t ton,
# 	AMand hid as amer; ml t,
# 	ALUSye ainasit,
# HATI	[ET
#
# iter:40799/50000 loss:2.431354284286499
# generated sequence: Whe k, d l G thewnay t ird, mianorn bl m f!
#
#
# Homl.
# 	INET  she hee, cknt whint alond rtlis  tit twh i
# iter:40899/50000 loss:2.448662042617798
# generated sequence: Whawn nd,
#
# HO	[TZ	Tos's o whe sure uslllllir D is fo h bir d ajould lillis lcishes it'tooleshenk.
#
# 	T
#
# iter:40999/50000 loss:2.4358396530151367
# generated sequence: Whetisemertaysentt  treshat nono d.
# Fowerdeeecaumy sheve ncee k ttell sond wingend,
# 	Frate
#
# MLoucurbe
#
# iter:41099/50000 loss:2.403062105178833
# generated sequence: Whce l al thalieabu icatoth y os; the m,
#
# 	[EThir amis d mpl arsyo meinon tols mlin lind th, s mirs,
#
# iter:41199/50000 loss:2.423126459121704
# generated sequence: What, al inghe f blor I trd, y?
#
#
# 	Wive! ther wieeanoo  hiatopid me:
# 	UDon; mad the h tisis.
# 	Wane sh
#
# iter:41299/50000 loss:2.400747299194336
# generated sequence: Whikerk man? t, tofa bud anowro tsertimy a plot PORe off mou hu  ise a jeathat,
# 	Whing ithargshe tur
#
# iter:41399/50000 loss:2.4289302825927734
# generated sequence: Wh, ILane t, ncoug's w INENGo t hthedrr aroupemealshteler lat tutotoftles the one vod wounofout by an
#
# iter:41499/50000 loss:2.434540271759033
# generated sequence: Wh
# 	Wistt be god arrouorarar:
# Hor
# 	HATto Courd towif fash s f ag the d, t ctwakee iery!
#
# 	refond?
# HAM
#
# iter:41599/50000 loss:2.422877073287964
# generated sequence: Wh ie Thatethinetheyout secche.
# HAS t .
# 	d t. is pendis Gr;
# Hand mme and tht averether!
#
# HARUI t he
#
#
#
# iter:41699/50000 loss:2.43609619140625
# generated sequence: Wer us ber p binokn hevegureaverel mamou wererd- her d he inimell veatlos t Whe. t'e,
# QUpr m ben s pi
#
# iter:41799/50000 loss:2.4380834102630615
# generated sequence: Whed stho thars s  fe, th be athe thelanome r,-	YNohett h be s thhietlimeean sseavearethae OSwitheng
#
# iter:41899/50000 loss:2.4602599143981934
# generated sequence: Whinorg, the'd por mot, f mpl,
#
#
# 	We
#
# 	YNSERNotherindimy enat be ne mlinongeseres
# 	OLD d wave, ant o.
#
# iter:41999/50000 loss:2.4178671836853027
# generated sequence: Wit s wretod l  ass:
# Fret Fupasorul thomed fe t-mally!
# S	[Exckild d mas s wn her stowour the other, n
#
# iter:42099/50000 loss:2.444894313812256
# generated sequence: Whofous IOnwld moste? t thetevethingeind, y the bed ct, Whinexgorf t him. onk,---tous se mir. ll ck;
#
# iter:42199/50000 loss:2.4192256927490234
# generated sequence: Wind hy serce'titheyofavet mathanghin-dondiores he ame ou nthengepus,
# 	US	NICLO g isor, o t frt ss pl
#
# iter:42299/50000 loss:2.4002459049224854
# generated sequence: Wh
# 	AELE	OSbnor tiane
# HAt, le Gof lid tr g ttiermpetiltie m te se t, Tovoupawh k  bll d w pior,
# 	ATRU
#
# iter:42399/50000 loss:2.431248426437378
# generated sequence: Whele withtang to GELENI'tous ssuthe itlescaimy is, Pomen ye;
# 	Thtthy lathare andgat an d; chu INostr
#
# iter:42499/50000 loss:2.424933433532715
# generated sequence: Whagoncou'ANTRNTZ	Burckerist houre; pecof-
# 	AUET	Whe ais t in.
# 	Whall
# 	t lind wray siosinthicetindh
#
#
# iter:42599/50000 loss:2.4193129539489746
# generated sequence: Wiswasen ha apsuro HERUDos horee me outroserethevere]
# 	Ifo d bearaildano!
#
# 	HAlethasige a ougl's mare
#
# iter:42699/50000 loss:2.4336931705474854
# generated sequence: Whe akisor ginrsis. orolo t sun t'n tal  IUDer
# LAmarcke wimor tof  tindeeincer ocofre, thaswow--I ane
#
# iter:42799/50000 loss:2.441807508468628
# generated sequence: Wit]
# 	TEENBun y, IUD r.
# 	S! opt pher nd
# 	ILAMLERD y,
# 	HANere w t
# 	sham by m d luil ghitonm  usis
# HAML
#
# iter:42899/50000 loss:2.430636405944824
# generated sequence: Who pile lloisthersan.
#
# 	HAMy timoly, as:
# HONankirs hileshe k: whed  mo fulesin bold; hartino my oke
#
# iter:42999/50000 loss:2.4317753314971924
# generated sequence: Wiend d d,
# 	OROprd s sepant llo d tt irdsthou are.
# 	MLExb'ssupe  thallindering heave; ke ole lot gsou
#
# iter:43099/50000 loss:2.4401912689208984
# generated sequence: Whe ato it mos, s oond, POL	GUS	INSRT
# 	IUExeasteef ag	Bureand INGofo windomyond.
# 	w a whe blfthy n f
#
# iter:43199/50000 loss:2.440716505050659
# generated sequence: Whed  ,
# 	imsurt,
# 	Hatere fouinolis mu hinthest h and my thale bed,
# 	Wegsimy aurdisshere IUDIOf et Got
#
# iter:43299/50000 loss:2.426290512084961
# generated sequence: Whe t Han weno  thavetat ano  th wsane, d mee e cprer: nd terarer.
# 	ou ad  lar a h s tare s.
# 	All, th
#
# iter:43399/50000 loss:2.4246740341186523
# generated sequence: Whous ge ibenofind: te. PDIUS	Whly PO	G y br kesthe, Careneere osilory,
# 	ACte t kad, y, Pre simontho
#
# iter:43499/50000 loss:2.4341611862182617
# generated sequence: Wist heneay a hur  d,
# 	INCOPONTET	Yon; t tow, usos HAMLAUS] ou.
# 	AMLUI w hy silay, d l an te ws
#
# 	Wh
#
# iter:43599/50000 loss:2.416020154953003
# generated sequence: Wouelithighivorileapancamy kewis. my n t way?
#
# 	AMLELUD it usther tespik 'sthie e deerfome s th there
#
# iter:43699/50000 loss:2.4329636096954346
# generated sequence: Wheapandee's uthin
# 	wor d m iksth ERNors;
#
#
#
# 	D ths,
#
# KIUDabtithe t benghe t lo het Cak,
# 	CLDELERCl .
#
# iter:43799/50000 loss:2.4211602210998535
# generated sequence: Whenghe my,---and wethu is llpurd, satiremhecoora
# 	Wh,
#
# 	Houre ftwidiso,  br;
# 	GUKI f h, n ndo: cly c
#
# iter:43899/50000 loss:2.4381277561187744
# generated sequence: Wh foryot y than, the'thac.
# Gund hemeellyofinomase bin	A	OLERATo me ise, indof rcoulluEn
#
#
# 	ANof thou
#
# iter:43999/50000 loss:2.4211888313293457
# generated sequence: Wer brd shenngham g kely sor'HAN wins, eme key they.
# 	Th igas ady sidork. pe'sean wicthasitavit,
# 	MAn
#
# iter:44099/50000 loss:2.4227380752563477
# generated sequence: Whe  wothant hy l f pofr d d sloulletarath odere azeaved I s stie Wheden torant ut plfery,  buld. qus
#
# iter:44199/50000 loss:2.4361326694488525
# generated sequence: Wichal. oveitour y thall ou aveamst aroures. Cobin pelit wan'the;
# LAMLUDET	I fe, ind, h istharenk ave
#
# iter:44299/50000 loss:2.431881904602051
# generated sequence: Whe relet homond o towe, thyoerkistiverattsast t.
# 	AT]
# 	TIUDILE	Wemy, is?
#
# HOLORUSETEToss it ak
# 	acak
#
# iter:44399/50000 loss:2.4163928031921387
# generated sequence: Wild.
# 	Asorr re
#
#
# 	T ird CET	MLomofr dimyoth we ty UINC d n:  t h ichaloourtrshithidoiso,
# 	DIOf ouril
#
# iter:44499/50000 loss:2.436375617980957
# generated sequence: Wondutimer y phayote.
# 	Whind t'tr.
#
# LAnoos thy!
# 	NCELARAnds hounowakin
# 	LESheco alo! be t adichel; op
#
# iter:44599/50000 loss:2.4349803924560547
# generated sequence: Wourccomy cedongoushes t waderer  mbesowhyom he athepesspa pl haghe,
#
#
# HAE	in
# 	Bun wathot wabe cher b
#
# iter:44699/50000 loss:2.4226908683776855
# generated sequence: Wulmyo y arllegrivingat GEn t ld stal?
# 	HA  t med wit'd. brs owithe,
#
# 	N theaing' d en arit.
# 	g t are
#
# iter:44799/50000 loss:2.3983311653137207
# generated sequence: Whit awor,
# 	To, thetllfas ndil
#
#
# 	erved no s CRAMAn thit re ats, e KI ware Gofo bothee mererviedimars
#
# iter:44899/50000 loss:2.429565191268921
# generated sequence: Wet beais
#
# POPORAThier, tath f  sererendriasute?
# HO, anth'thesean ' s o fa 'T]
#
# SET	Titerinmas  asthe
#
# iter:44999/50000 loss:2.4279346466064453
# generated sequence: Whe ounghe t, ant NS	T	T	A	[ET	fodelles, PHadber rnes.
#
#
# HORDO. m ur. wheh
# 	TZ	Ye linours, f eave t s
#
# iter:45099/50000 loss:2.4129343032836914
# generated sequence: We thanciet,
# GUnghaiperm go thyotow weawon qurr.
# 	aikefo frdges blde'stharonom il. ars ave ld pth ith
#
# iter:45199/50000 loss:2.4279348850250244
# generated sequence: Won;
# 	G rwaingofowancounrd s:
#
#
#
# 	T	T	Thy, ponler pe it we toure lt mar inem cet t bl, n m; myo oulac
#
# iter:45299/50000 loss:2.427269220352173
# generated sequence: Wh t myomaretinthayouthised aificeagee he, be.
# 	Casungabetilovelfot goueviveneroulalened llind, waken
#
# iter:45399/50000 loss:2.4308955669403076
# generated sequence: Win l, f LAMLAMathe nto wed
#
# 	GEENGingher sown l s f are chigo serdgr ier thiead I d ss hof mould so
#
# iter:45499/50000 loss:2.433534622192383
# generated sequence: Whob pa o HAso'   my
# Hangriseet eear KIfowee lovesifin'lllo is]  n, pe sseno, he t: wnd,  f itherele
#
# iter:45599/50000 loss:2.4317123889923096
# generated sequence: Whem mai sth otherand 'sisse oforld cencondm ore my meresere hathas ay  y crf hare
# 	ACRAMLONIt ll mea
#
# iter:45699/50000 loss:2.445854902267456
# generated sequence: Whet h actichalo! ur.
# 	| adma nlonothanowher f inomeas thig he sennovine
# 	 wacost tand lomlune mr ata
#
# iter:45799/50000 loss:2.4146981239318848
# generated sequence: Whed qu y ow ant, do, thalanff t y t nd I ad; cey heu il m il nits?
#
# HAowe t t.
# 	Ho ngr--a s t se mew
#
# iter:45899/50000 loss:2.414898157119751
# generated sequence: Wofe dd cere AMLOPe alle me  t lly'ar, spitut, seag wime per o
# 	AThallor withighoope.
# 	lartis Whal dy
# iter:45999/50000 loss:2.4320549964904785
# generated sequence: Witeg bl, tik, h d nd f th mus wnd
#
# AMLEnde Gine cut y tyous?
# 	 alorsk,
# 	Anto s icose tor pe mant mis
#
# iter:46099/50000 loss:2.4472336769104004
# generated sequence: Wiotelen m.
#
# ]
# 	T	s f y ie
# HAUDIAMLOenge? Berithe;
#
# A	TERT	[ENIIAs t? t:
# 	TINCavid sada ve s mourat c
#
# iter:46199/50000 loss:2.436368942260742
# generated sequence: Whiey y, s dine
#
#
# HORTherams's!
#
#
# LOeno'ly ive e theai tith LAnf
# 	I k t'TI f y l OLDo we, why O	ye he
#
# iter:46299/50000 loss:2.439683437347412
# generated sequence: Wimyor is to, isd plourr y ak,
# 	MLExgo, y
#
# 	[Exind nino.
#
#
# HAnd, phas-sesprd, fallur tin In:
#
#
#
# 	Wikn
#
# iter:46399/50000 loss:2.413525342941284
# generated sequence: Weeaton,
# 	m Pry. alcoubeenose te, heed uzereng fut: y s
# 	TIfard; twinde Hantoabue nothathea casmeaurg
#
# iter:46499/50000 loss:2.409013509750366
# generated sequence: Whowoonsk. wo win'e metnepo w,
#
# OCLE	Ghad p. f
# 	Wistemusk s is noou, Moushise 'l IUSond sth Whe sstaf
#
# iter:46599/50000 loss:2.4205822944641113
# generated sequence: Whers ie ang g: Sakissean y.
# KI ot;
# Hain igase, arimy lendis fad p orisctrofeeakstik:
# 	migath cke s s
#
# iter:46699/50000 loss:2.4239983558654785
# generated sequence: Whel, HAMLAETIO	Todit boururs end?
# 	I han. f marol n'd towrist igwon	TI'sisideallENCLen thart whed, p
#
# iter:46799/50000 loss:2.439901828765869
# generated sequence: Weand d ato qutend ouck phe orud. t ngef I An fowhe we ve ierthee iinkng	Tour]
# 	FRUE	That. e s onkn,
#
# iter:46899/50000 loss:2.425886392593384
# generated sequence: Whitou jeteamy. O	O, t I thinecago acut, hthyoud our  torsilpir s.
# 	You ht. as, henl benootkes
#
# 	By
#
# iter:46999/50000 loss:2.416811943054199
# generated sequence: Wir Yonjet: hiro bd ce Howes,
# Bere s t amou f  wold,
# 	Theastry s haisealifals sod bld! ane's anayanou
#
# iter:47099/50000 loss:2.420459747314453
# generated sequence: Witely m Buthower and an lede mmatinit wrreasth IAMLEMLAThelisas t fitn tr yo ase both,
# 	Wid,
# 	MAENS
#
# iter:47199/50000 loss:2.4325647354125977
# generated sequence: Wiratomorrlay blowirk tn horchandonind isigou of be agscucout fatharagu nd, aleleve wigels ne hrttith
#
# iter:47299/50000 loss:2.4363744258880615
# generated sequence: We fape wh,
# 	thathane.
# RUSCouitos  isyont thevout yous ieayo kerthelespemorirat]
#
#
# 	[Esmot PON o te
#
#
#
# iter:47399/50000 loss:2.4247357845306396
# generated sequence: Wive therirt he;
# 	HATe e,
#
# HAMLERCf thyous blerot, w;
#
#
# 	Th deincle can: y nore us; theerve s wo ug s
#
# iter:47499/50000 loss:2.418804407119751
# generated sequence: Wiethan eeran pl ais g: t ig oll iso wasovewis.
# 	AMLE	Youlingssticat w he ungs oway, brou tous ithis
#
# iter:47599/50000 loss:2.426837682723999
# generated sequence: Whesct brt, wedotha wer aus? myomomiblincierd?
# 	IACLDENCERSEne  LEThe lle! thene bono yofee-crare t j
#
# iter:47699/50000 loss:2.4462833404541016
# generated sequence: Whel
#
#
# 	MLEExco hit de we ike whanghy t'le hel ldache at r ff e fowisok indimurain t st, buriso s usi
#
# iter:47799/50000 loss:2.4351863861083984
# generated sequence: Wil bbu be.
# 	TZ	Whit Par.
# 	Thamyas!
# 	Sorrs, Ousthiness pasthe.
# 	ARDERAT	USThalerereaind rcamert, m d,
#
# iter:47899/50000 loss:2.4152321815490723
# generated sequence: Whe.
# 	Whokereentothit thotres ind. st is ad. rcl eng suse pperougurdlacacht DUS	Ser, y sha br had our
#
# iter:47999/50000 loss:2.412191390991211
# generated sequence: Whooon inch, t at yove, y Cowrirononout handafikinthourer, hae.
# 	[ETELERAMLERORNo h.
# 	Thiss
#
# HO d, ay
#
# iter:48099/50000 loss:2.446385145187378
# generated sequence: We m ai'lllllin indu ntham, thyostacon, he phe d ceaiokis sity wil hore orithel's wis:
#
# 	Batcl PONI O
#
# iter:48199/50000 loss:2.4399538040161133
# generated sequence: We
# 	Toma, at s he mipestcorustas igl ile rourind  younaks hat fin hilivetar hare
# 	 cor,
#
#
# 	Th stsersp
#
# iter:48299/50000 loss:2.4052319526672363
# generated sequence: Wh
# 	ldale bue okigheches
# 	[ERNThe ooutexeam s ded mourak  matherspeshewikllqu: g:
#
#
# RACRDo't to's
# 	[E
#
# iter:48399/50000 loss:2.417191982269287
# generated sequence: Whohthemisthickeloundmu su thit se you me.
# HAnd, mt isiny'd
# 	The. bu, selithir V
# 	Tat uland cusu wt
#
#
#
# iter:48499/50000 loss:2.4267611503601074
# generated sequence: Whayr chou, cethinsthe
#
#
# 	AUDavemak gooust grman	ICRAT	TRA saur!
# 	NG the, t or
# 	Got, wak chidouly fis
#
# iter:48599/50000 loss:2.440944194793701
# generated sequence: Wive!
# 	ORDETINT	BOLACERDounobuth aisinfou demfand seat te, n ce, moupofu,
#
#
# 	Wiry,
#
#
# 	y  w'e l  charo
#
# iter:48699/50000 loss:2.4371933937072754
# generated sequence: Whamid hef'eno, 'dinethatowis; oanofo
#
# LERThes f IOLOPfoot? fe.
# 	STRETIONESt myode.
# 	Wirseatimmy mnd
#
# iter:48799/50000 loss:2.4358580112457275
# generated sequence: Wh;
# 	Whoon wn torifanthe a whate ndothenout, ghanthe n thit	GELAUEn phad? POR's at d tan nsayofrine c
#
# iter:48899/50000 loss:2.4210219383239746
# generated sequence: Whe inolo'toun me.
#
# 	Anerie CRN ano ulday st I m d.
# Go mmalchedethare cee, ar iknd ly  th im, IUI's a
#
# iter:48999/50000 loss:2.40273118019104
# generated sequence: Wiren'
# HAn p outhereeth Lanorthe winemo go lowa tinind marourd Ghtiker d cot triere delind?
#
# 	egrnots
#
# iter:49099/50000 loss:2.440762996673584
# generated sequence: Whepanos awoket s irt: bllisid pt s t othincouerome an t hin]
#
# 	Wu,
#
# 	Fiveper vere?
# Qup ou  utiotug a
#
# iter:49199/50000 loss:2.417778491973877
# generated sequence: Whean
# ORTIUSo, shourourcand, ldilecast, as t t, secre id g? y y bed,
# 	LExis tomes, itt gholin!
# Of ho
#
# iter:49299/50000 loss:2.420599937438965
# generated sequence: Wey ore t
# KI Lo'my gupu panfak, avevo jomew by! hte of oray'
# 	Thy o:
#
# 	Vivetprs
# 	Whennsde of rois wis
#
# iter:49399/50000 loss:2.4266765117645264
# generated sequence: Wind, ar we, insindasinntie che KICllof mathiayongham IUST	Foty y than ce se I l'er tstor wo othirtha
#
# iter:49499/50000 loss:2.4392929077148438
# generated sequence: Whe wre;
# 	T	A	as  teanout ofoudon.
# 	Thasth or thad,
# SENGEN fs
#
# 	Worat care f n mer toa ms be g g] d,
#
#
# iter:49599/50000 loss:2.4362785816192627
# generated sequence: Wh shat nan, gulis l,
# 	ml.
# FRThanditond cenon'texiful memichin ouligsthass k, ks yo I t, t bulelor: n
#
# iter:49699/50000 loss:2.4306905269622803
# generated sequence: Whitoushtthat,
# 	at Qu,
# 	Bureve apans, thiswithelons tosthir:]
# 	[Towey th anthit	A hilyo tive ay,
#
# 	TZ
#
# iter:49799/50000 loss:2.4400997161865234
# generated sequence: We be Wio cosudispot thers ry.
# 	Wiotath th oveeppe
# 	[E	qu ildande s amothaveror ol iry nty the hr bus
#
# iter:49899/50000 loss:2.424496650695801
# generated sequence: Windooous QUS	O, re
# 	[Andrngat nge fouthathead s,
# 	Whe hehed, ghirtouren s old bote?
# 	Han.  tr we NAT
#
# iter:49999/50000 loss:2.4245312213897705
# generated sequence: Whas w. t te t our-sy luneerd the in, ouort;
# HAnos, malinout s y?
#
# 	Ithed waing-lene ghas s s d cotha

# %% [markdown]
# ## Evaluation

# %%
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(all_losses)
plt.show()

# %%
print(eval_step(net, predicted_len=100))
# Out:
# Why, stherr maved f ma atowr iare se tr. th, y l moft,
# LD winref ar me ousa hans t it fot--
#
# 	ye.
